# %%
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
all_stats = np.load('bolplanck_test.npz')

# %%
all_stats.keys()
# Out:
# ['ngals', 'rp', 'deltasigma', 'param']

# %%
rp = all_stats['rp'][0]
print rp
# Out:
# [  0.05282343   0.08333484   0.13146998   0.20740853   0.32721003
#    0.51621023   0.81437908   1.28477361   2.02687332   3.1976182
#    5.0445985    7.95841545  12.5552859 ]

# %%
def A_to_index(Acen,Asat):
    idx0 = (Acen+1.)/0.05*41+(Asat+1.)/0.05
    return int(idx0)

# %%
ds = all_stats['deltasigma']

# %%
plt.plot(rp,ds[A_to_index(0,0)])
plt.loglog()
# Out:
# []

# %%
ds[A_to_index(0,0)]
# Out:
# array([  5.11829322e+09,   3.63512678e+09,   2.60157090e+09,
#          1.83940561e+09,   1.30859855e+09,   9.53502680e+08,
#          6.88733528e+08,   4.77383556e+08,   3.09744613e+08,
#          1.89532913e+08,   1.23773434e+08,   8.60429149e+07,
#          6.14463025e+07])

# %%
standard_ds = ds[A_to_index(0,0)]

# %%
def ratio_at_r(Acen,Asat,rp_i):
    ratio = ds[A_to_index(Acen,Asat),rp_i]/standard_ds[rp_i]
    return ratio

# %%
ratio_all = np.zeros((13,41,41))

# %%
for i in range(13):
    for j in range(41):
        for k in range(41):
            ratio_all[i,j,k] = ratio_at_r(-1+0.05*j,-1+0.05*k,i)

# %%
for i in range(13):
    plt.figure()
    plt.imshow(ratio_all[i],cmap='bwr',vmin=0,vmax=1.4,interpolation='None')
    plt.colorbar()
    plt.title(rp[i])

# %%
for i in range(13):
    plt.figure()
    plt.imshow(ratio_all[i],cmap='bwr',interpolation='None')
    plt.colorbar()
    plt.title(rp[i])
